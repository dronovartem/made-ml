# %%
from nltk.util import ngrams
from collections import defaultdict
import re
import numpy as np
from itertools import product
from tqdm import tqdm

# %% [markdown]
# ## Часть 1.

# %% [markdown]
# Реализуйте базовый частотный метод по Шерлоку Холмсу:
# - подсчитайте частоты букв по корпусам (пунктуацию и капитализацию можно просто опустить, а вот пробелы лучше оставить);
# - возьмите какие-нибудь тестовые тексты (нужно взять по меньшей мере 2-3 предложения, иначе вряд ли сработает), зашифруйте их посредством случайной перестановки символов;
# - расшифруйте их таким частотным методом.

# %% [markdown]
# Решение:
#
# Напишем функции, осуществляющие подсчет частот в файле (для оценки теоретических частот языка) и в фрагменте текста:

# %%
def get_ngrams_freqs(filepath, ngram_size=1):
    tuple_freqs = defaultdict(int)
    ngram_count = 0
    buf = ""
    with open(filepath, "r", encoding="utf-8") as file:
        for line in file:
            clear_line = buf + " ".join(re.findall(r'[А-я]+', line)).lower()
            for ng in ngrams(clear_line, n=ngram_size):
                tuple_freqs[ng] += 1
            clear_line += " "
            ngram_count += len(clear_line) - ngram_size
            buf = clear_line[-ngram_size:]
    output = defaultdict(int)
    for sym, freq in tuple_freqs.items():
        output["".join(list(sym))] = freq / ngram_count
    return output


def get_sample_freqs(text, ngram_size=1):
    tuple_freqs = defaultdict(int)
    clear_text = " ".join(re.findall(r'[А-я]+', text)).lower()   
    for ng in ngrams(clear_text, n=ngram_size):
            tuple_freqs[ng] += 1
    ngram_count = len(clear_text) - ngram_size
    output = {}
    for sym, freq in tuple_freqs.items():
        output["".join(list(sym))] = freq / ngram_count
    return output

etalon_freqs = get_ngrams_freqs('AnnaKarenina.txt')
alphabet = ' абвгдежзийклмнопрстуфхцчшщъыьэюя'

# %% [markdown]
# Также реализуем функции, осуществляющие шифр простой замены и дешифрование сообщения. Для оценки качества также потребуется метрика качества. Будем пользоваться точностью - долей верно угаданных символов шифра замены:

# %%
def simple_substitution_cipher(
    plaintext,
    alphabet=' абвгдежзийклмнопрстуфхцчшщъыьэюя',
    seed=42):
    np.random.seed(seed)
    permute = np.random.permutation(list(alphabet))
    substitution = {
        k: v for k, v in zip(alphabet, permute)
    }
    return ("".join([substitution[sym] for sym in plaintext]), substitution)


def decrypt_substitution_cipher(cipher_text, decrypt_substitution):
    return "".join(decrypt_substitution[sym] for sym in cipher_text)


def decryption_quality(pred_sub, cipher_sub):
    success_count = 0
    for cipher_sym, plain_sym in pred_sub.items():
        if cipher_sub[plain_sym] == cipher_sym:
            # print(plain_sym, "->", cipher_sym)
            success_count += 1
    return success_count / len(pred_sub)

# %% [markdown]
# Выберем фрагмент текста из произведения и зашифруем его случайной перестановкой символов:

# %%
sample_text = 'потребность жизни увеличенная выздоровлением была так сильна и условия жизни были так новы и приятны что анна чувствовала себя непростительно счастливою чем больше она узнавала вронского тем больше она любила его она любила его за его самого и за его любовь к ней полное обладание им было ей постоянно радостно близость его ей всегда была приятна все черты его характера который она узнавала больше и больше были для нее невыразимо милы'

# %%
cipher_text, cipher_substitution = simple_substitution_cipher(sample_text)
cipher_text
# Out:
# 'ачвбтщкчьвжюф лк юъртд стккоыюряличбчрдтк тмющядоювопюь джкою юъьдчр ыюф лк ющяд ювопюкчряю юаб ывкяюсвчюоккоюсърьврчродоюьтщыюктабчьв втджкчюьсоьвд рчнюстмющчджштючкоюълкородоюрбчкьпчзчювтмющчджштючкоюднщ доютзчючкоюднщ доютзчюлоютзчюьомчзчю юлоютзчюднщчржюпюктгюачдкчтючщдоиок тю мющядчютгюачьвчыккчюбоичьвкчющд лчьвжютзчютгюрьтзиоющядоюаб ывкоюрьтюстбвяютзчюэобопвтбоюпчвчбягючкоюълкородоющчджштю ющчджштющяд юидыюкттюктрябол мчюм дя'

# %% [markdown]
# Для дешифровки с помощью n-грамм символов будем использовать следующий класс, который осуществляет жадный алгоритм сопоставления частот открытого и шифртекстов (для букв - сопоставляет символы по частоте, для n-грам - ищет наиболее вероятную n-грамму открытого текста, которая может быть сопоставлена рассматриваемой в открытом тексте):

# %%
class NgramDecryptor:
    def __init__(
        self,
        ngram_size=1,
        etalon_freqs=etalon_freqs):
        self.ngram_size = ngram_size
        self.most_popular_origin = [sym for sym, _ in sorted(etalon_freqs.items(), key=lambda x: x[1], reverse=True)]
        self.most_popular_cipher = None
        self.cipher_syms = None
        self.decrypt_substitution = {}
    
    def fit(self, cipher_text):
        cipher_text_freqs = get_sample_freqs(cipher_text, ngram_size=self.ngram_size)
        self.most_popular_cipher = [sym for sym, freq in sorted(cipher_text_freqs.items(), key=lambda x: x[1], reverse=True)]
        self.cipher_syms = set(cipher_text)
        for i in range(len(self.most_popular_cipher)):
            j = 0
            try:
                while not self.__could_assign(
                    self.most_popular_cipher[i],
                    self.most_popular_origin[j],):
                    j += 1
                for ng_c, ng_e in zip(
                    self.most_popular_cipher[i],
                    self.most_popular_origin[j]):
                    self.decrypt_substitution[ng_c] = ng_e
                    if ng_c in self.cipher_syms:
                        self.cipher_syms.remove(ng_c)
                if not len(self.cipher_syms):
                    break
            except IndexError: # haven't found good mapping, better skip it
                pass

    def __could_assign(self, cipher_ngram, etalon_ngram):
        # ngrams syms was added before, no reason to do this step
        if not self.cipher_syms.intersection(set(cipher_ngram)):
            return False
        
        loc_dict = {} # keep it to avoid cases like 'aba' -> 'gbx',
                      # where `a` has to be 'a': 'g' and 'x'.

        for sym_c, sym_e in zip(cipher_ngram, etalon_ngram):
            if sym_c in self.decrypt_substitution.keys():
                if self.decrypt_substitution[sym_c] != sym_e:
                    return False
                else:
                    pass # mapped in global dict
            else:
                if sym_e in self.decrypt_substitution.values():
                    return False
                else:
                    if sym_e not in loc_dict.values():
                        loc_dict[sym_c] = sym_e
                    else:
                        if sym_c not in loc_dict or loc_dict[sym_c] != sym_e:
                            return False
        return True

    def predict(self, cipher_text):
        return decrypt_substitution_cipher(cipher_text, self.decrypt_substitution)

# %% [markdown]
# Проверим качество дешифрования используя частоты символов:

# %%
dec = NgramDecryptor(ngram_size=1)
dec.fit(cipher_text)
dec.predict(cipher_text)
# Out:
# 'ыоскалнорсм хтунт чваитганнея вдузоковиантаь лдие себ ртимне т чриовтя хтунт лдит себ новд т ыктяснд гсо енне гчврсвовеие раля наыкорстсаимно ргерситвож гаь лоимйа оне чуневеие вконрбопо саь лоимйа оне ижлтие апо оне ижлтие апо уе апо реьопо т уе апо ижловм б наш ыоиноа олиезента ть лдио аш ыорсоянно кезорсно литуорсм апо аш врапзе лдие ыктясне вра гаксд апо юекебсаке босокдш оне чуневеие лоимйа т лоимйа лдит зия наа навдкеутьо ьтид'

# %%
decryption_quality(dec.decrypt_substitution, cipher_substitution)
# Out:
# 0.17857142857142858

# %% [markdown]
# 4 символа были сопоставлены верно, однако текст все равно остается нечитаемым.

# %% [markdown]
# ## Часть 2.

# %% [markdown]
# Вряд ли в результате получилась такая уж хорошая расшифровка, разве что если вы брали в качестве тестовых данных целые рассказы. Но и Шерлок Холмс был не так уж прост: после буквы E, которая действительно выделяется частотой, дальше он анализировал уже конкретные слова и пытался угадать, какими они могли бы быть. Я не знаю, как запрограммировать такой интуитивный анализ, так что давайте просто сделаем следующий логический шаг:
# - подсчитайте частоты биграмм (т.е. пар последовательных букв) по корпусам;
# - проведите тестирование аналогично п.1, но при помощи биграмм.

# %% [markdown]
# Сделаем аналогичную процедуру с биграммами текста:

# %%
etalon_bigram_freqs=get_ngrams_freqs('AnnaKarenina.txt', ngram_size=2)
dec = NgramDecryptor(ngram_size=2,  etalon_freqs=etalon_bigram_freqs)
dec.fit(cipher_text)
dec.predict(cipher_text)
# Out:
# 'пекхинтескл зачта вмигадиттоя мычжехемгитаиь ныго коб саглто а всгемая зачта ныга коб темы а пхаякты дке отто двмскмемого синя типхескакиглте сдоскгамеш диь неглуи ето вчтомого мхетсбере киь неглуи ето гшнаго ире ето гшнаго ире чо ире соьере а чо ире гшнемл б тий пегтеи енгожотаи аь ныге ий пескеятте хожескте нгаческл ире ий мсиржо ныго пхаякто мси дихкы ире эохобкихо бекехый ето вчтомого неглуи а неглуи ныга жгя тии тимыхочаье ьагы'

# %%
decryption_quality(dec.decrypt_substitution, cipher_substitution)
# Out:
# 0.21428571428571427

# %% [markdown]
# Получилось несколько успешнее, однако это мало о чем говорит, ведь текст по-прежнему нечитаем.

# %% [markdown]
# ## Часть 3.

# %% [markdown]
# Но и это ещё не всё: биграммы скорее всего тоже далеко не всегда работают. Основная часть задания — в том, как можно их улучшить:
# - предложите метод обучения перестановки символов в этом задании, основанный на MCMC-сэмплировании, но по-прежнему работающий на основе статистики биграмм;
# - реализуйте и протестируйте его, убедитесь, что результаты улучшились.

# %% [markdown]
# В данном задании будем рассматривать МСМС-сэмплинг как способ нахождения максимума плотности апостериорной вероятности подстановки при условии наблюдаемого текста.
# Будем осуществлять перестановку случайно взятой пары символов, основываясь на изменении вероятностей наблюдения дешифрованных (с помощью текущей и модернизированной подстановок) текстов. Эти вероятности будем вычислять на основе статистике биграм открытых текстов. Из технических соображений будет оперировать логарифмами правдоподобий текстов. В силу симметрии функционала замены случайной пары символов, МСМС шаг выглядит следующим образом:
#
# Пусть на шаге $t$ мы находимся в состоянии $d_t$ (то есть имеем некоторую перестановку). Здесь также отметим, что в качестве начального приближения можно воспользоваться перестановкой, основанной на дешифровании с помощью частот знаков/биграмм.
#
# 1) Проводим случайную перестановку двух символов в $d_t$, получаем перестановку $d'$.
#
# 2) Расшифровываем шифртекст $text$ используя перестановки $d_t$ и $d'$ и вычисляем правдоподобия полученных открытых текстов.
#
# 3) Вычисляем $a = \frac{p(text|d')}{p(text|d_t)}$
#
# 4) Если $a >= 1$, тогда $d_{t+1} = d'$. Иначе, $d_{t+1} = d'$ с вероятностью $a$ или $d_{t+1}=d_t$ с вероятностью $1-a$ соответственно.

# %% [markdown]
# Из технических соображений, вычислим набор значений логарифмов вероятностей.
# Кроме того, возможно потребуется дополнить перестановку до полной (в наблюдаемом шифртексте мощность алфавита может быть меньше, чем в открытом тексте).

# %%
eps = 1e-6
etalon_log_freqs = {}
for i, j in product(alphabet, repeat=2):
    etalon_log_freqs[i + j] = np.log(etalon_bigram_freqs[i + j] + eps)

# %%
def extend_substitution_to_full(sub, etalon_freqs):
    most_popular_origin = [sym for sym, freq in sorted(etalon_freqs.items(), key=lambda x: x[1], reverse=True)]
    for sym in most_popular_origin:
        if sym not in sub.keys():
            sub[sym] = sym
    return sub
    
decrypt_substitution = extend_substitution_to_full(dec.decrypt_substitution, etalon_freqs)

# %% [markdown]
# Реализуем функцию, осуществляющую МСМС-сэмплирование для указанной задачи.

# %%
def mcmc_sampling(
    sample_text,
    init_substitution,
    alphabet=' абвгдежзийклмнопрстуфхцчшщъыьэюя',
    etalon_log_freqs=etalon_log_freqs,
    n_steps=10000,
    ngram_size=2,
    seed=123,
):
    np.random.seed(seed)
    best_sub = None
    best_llh = -np.inf
    alphabet_symbols = list(alphabet)
    curr_sub = init_substitution.copy()
    curr_sub_llh = __text_loglikelihood(
        decrypt_substitution_cipher(sample_text, curr_sub),
        etalon_log_freqs, ngram_size=ngram_size)
    for _ in tqdm(range(n_steps)):
        # create MC step
        idx_first = np.random.choice(alphabet_symbols)
        idx_second = np.random.choice(alphabet_symbols)
        next_sub = curr_sub.copy()
        next_sub[idx_first], next_sub[idx_second] = curr_sub[idx_second], curr_sub[idx_first]
        # score to either reject or accept
        next_sub_decrypt_text = decrypt_substitution_cipher(sample_text, next_sub)
        next_sub_llh = __text_loglikelihood(next_sub_decrypt_text, etalon_log_freqs, ngram_size=ngram_size)
        if __mcmc_accept(curr_sub_llh, next_sub_llh):
            curr_sub = next_sub.copy()
            curr_sub_llh = next_sub_llh
            if curr_sub_llh > best_llh:
                best_sub = curr_sub.copy()
                best_llh = curr_sub_llh
                print('\nNew best llh: ', best_llh)
                print('Best decryption: ', next_sub_decrypt_text)
    return best_sub


def __mcmc_accept(curr_llh, next_llh):
    prob = min(1, np.exp(next_llh - curr_llh))
    if prob >= 1:
        return True
    else:
        return np.random.random() < prob


def __text_loglikelihood(text, etalon_log_freqs, ngram_size=2):
    llh = 0
    for i in range(len(text) - ngram_size + 1):
        llh += etalon_log_freqs[text[i:i + ngram_size]]
    return llh

# %% [markdown]
# Запустим и оценим результаты (здесь в качестве начального приближения используется перестановка, основанная на частотах встречаемости биграмм):

# %%
best_substitution = mcmc_sampling(cipher_text, decrypt_substitution)
print("\n\nBest decryption: \n", decrypt_substitution_cipher(cipher_text, best_substitution))
print("Accuracy: ", decryption_quality(best_substitution, cipher_substitution))
# Out:
#   7%|▋         | 746/10000 [00:00<00:02, 3628.22it/s]
# New best llh:  -2795.138545292259
# Best decryption:  пекхинтескл зачта вмигадиттоя мычжехемгитаиь ныго коб саглто а всгемая зачта ныга коб темы а пхаякты дке отто двмскмемого синя типхескакиглте сдоскгамеш диь неглуи ето вчтомого мхетсбере киь неглуи ето гшнаго ире ето гшнаго ире чо ире соьере а чо ире гшнемл б тий пегтеи енгожотаи аь ныге ий пескеятте хожескте нгаческл ире ий мсиржо ныго пхаякто мси дихкы ире эохобкихо бекехый ето вчтомого неглуи а неглуи ныга жгя тии тимыхочаье ьагы
#
# New best llh:  -2789.3485154624204
# Best decryption:  пекхинтескл зачта вмигаьиттоя мычжехемгитаид ныго коб саглто а всгемая зачта ныга коб темы а пхаякты ьке отто ьвмскмемого синя типхескакиглте сьоскгамеш ьид неглуи ето вчтомого мхетсбере кид неглуи ето гшнаго ире ето гшнаго ире чо ире содере а чо ире гшнемл б тий пегтеи енгожотаи ад ныге ий пескеятте хожескте нгаческл ире ий мсиржо ныго пхаякто мси ьихкы ире эохобкихо бекехый ето вчтомого неглуи а неглуи ныга жгя тии тимыхочаде дагы
#
# New best llh:  -2783.5168808023914
# Best decryption:  пекхинтескл зачта вмигаьиттоя мычжехемгитаид ныго коб саглто а всгемая зачта ныга коб темы а пхаякты ьке отто ьвмскмемого синя типхескакиглте сьоскгамеш ьид неглуи ето вчтомого мхетсбере кид неглуи ето гшнаго ире ето гшнаго ире чо ире содере а чо ире гшнемл б тий пегтеи енгожотаи ад ныге ий пескеятте хожескте нгаческл ире ий мсиржо ныго пхаякто мси ьихкы ире еохобкихо бекехый ето вчтомого неглуи а неглуи ныга жгя тии тимыхочаде дагы
#
# New best llh:  -2781.3805448075655
# Best decryption:  пекхинтескл зачта вмибаьиттоя мычжехембитаид ныбо ког саблто а всбемая зачта ныба ког темы а пхаякты ьке отто ьвмскмемобо синя типхескакиблте сьоскбамеш ьид неблуи ето вчтомобо мхетсгере кид неблуи ето бшнабо ире ето бшнабо ире чо ире содере а чо ире бшнемл г тий пебтеи енбожотаи ад ныбе ий пескеятте хожескте нбаческл ире ий мсиржо ныбо пхаякто мси ьихкы ире еохогкихо гекехый ето вчтомобо неблуи а неблуи ныба жбя тии тимыхочаде дабы
#
# New best llh:  -2757.7415330318486
# Best decryption:  еекхинтескл зачта вмибаьиттоя мычжехембитаид ныбо ког саблто а всбемая зачта ныба ког темы а ехаякты ьке отто ьвмскмемобо синя тиехескакиблте сьоскбамеш ьид неблуи ето вчтомобо мхетсгере кид неблуи ето бшнабо ире ето бшнабо ире чо ире содере а чо ире бшнемл г тий еебтеи енбожотаи ад ныбе ий еескеятте хожескте нбаческл ире ий мсиржо ныбо ехаякто мси ьихкы ире похогкихо гекехый ето вчтомобо неблуи а неблуи ныба жбя тии тимыхочаде дабы
#
# New best llh:  -2714.5309901762016
# Best decryption:  еекхинтеску зачта вмибаьиттоя мычжехембитаид ныбо ког сабуто а всбемая зачта ныба ког темы а ехаякты ьке отто ьвмскмемобо синя тиехескакибуте сьоскбамеш ьид небули ето вчтомобо мхетсгере кид небули ето бшнабо ире ето бшнабо ире чо ире содере а чо ире бшнему г тий еебтеи енбожотаи ад ныбе ий еескеятте хожескте нбаческу ире ий мсиржо ныбо ехаякто мси ьихкы ире похогкихо гекехый ето вчтомобо небули а небули ныба жбя тии тимыхочаде дабы
#
# New best llh:  -2714.00017480441
# Best decryption:  декхинтеску зачта вмибаьиттоя мычжехембитаие ныбо ког сабуто а всбемая зачта ныба ког темы а дхаякты ьке отто ьвмскмемобо синя тидхескакибуте сьоскбамеш ьие небули ето вчтомобо мхетсгере кие небули ето бшнабо ире ето бшнабо ире чо ире соеере а чо ире бшнему г тий дебтеи енбожотаи ае ныбе ий дескеятте хожескте нбаческу ире ий мсиржо ныбо дхаякто мси ьихкы ире похогкихо гекехый ето вчтомобо небули а небули ныба жбя тии тимыхочаее еабы
#
# New best llh:  -2693.9555804705537
# Best decryption:  декхинтеску зачта ьмибавиттоя мычжехембитаие ныбо ког сабуто а ьсбемая зачта ныба ког темы а дхаякты вке отто вьмскмемобо синя тидхескакибуте своскбамеш вие небули ето ьчтомобо мхетсгере кие небули ето бшнабо ире ето бшнабо ире чо ире соеере а чо ире бшнему г тий дебтеи енбожотаи ае ныбе ий дескеятте хожескте нбаческу ире ий мсиржо ныбо дхаякто мси вихкы ире похогкихо гекехый ето ьчтомобо небули а небули ныба жбя тии тимыхочаее еабы
#
# New best llh:  -2687.2702240823137
# Best decryption:  докхинтоску зачта ьмибавиттея мычжохомбитаие ныбе кег сабуте а ьсбомая зачта ныба кег томы а дхаякты вко етте вьмскмомебе синя тидхоскакибуто свескбамош вие нобули оте ьчтемебе мхотсгоро кие нобули оте бшнабе иро оте бшнабе иро че иро сееоро а че иро бшному г тий добтои онбежетаи ае ныбо ий доскоятто хежоскто нбачоску иро ий мсирже ныбе дхаякте мси вихкы иро пехегкихе гокохый оте ьчтемебе нобули а нобули ныба жбя тии тимыхечаео еабы
#
# New best llh:  -2662.132065080625
# Best decryption:  докхинтоску зачта ьбимавиттея бычжохобмитаие ныме кег самуте а ьсмобая зачта ныма кег тобы а дхаякты вко етте вьбскбобеме синя тидхоскакимуто свескмабош вие номули оте ьчтебеме бхотсгоро кие номули оте мшнаме иро оте мшнаме иро че иро сееоро а че иро мшнобу г тий домтои онмежетаи ае нымо ий доскоятто хежоскто нмачоску иро ий бсирже ныме дхаякте бси вихкы иро пехегкихе гокохый оте ьчтебеме номули а номули ныма жмя тии тибыхечаео еамы
#
# New best llh:  -2650.5493490616827
# Best decryption:  докхинтоску зачта шбимавиттея бычжохобмитаие ныме кег самуте а шсмобая зачта ныма кег тобы а дхаякты вко етте вшбскбобеме синя тидхоскакимуто свескмабоь вие номули оте шчтебеме бхотсгоро кие номули оте мьнаме иро оте мьнаме иро че иро сееоро а че иро мьнобу г тий домтои онмежетаи ае нымо ий доскоятто хежоскто нмачоску иро ий бсирже ныме дхаякте бси вихкы иро пехегкихе гокохый оте шчтебеме номули а номули ныма жмя тии тибыхечаео еамы
#
# New best llh:  -2641.5117233659685
# Best decryption:  докхинтоску залта шбимавиттея былжохобмитаие ныме кег самуте а шсмобая залта ныма кег тобы а дхаякты вко етте вшбскбобеме синя тидхоскакимуто свескмабоь вие номучи оте шлтебеме бхотсгоро кие номучи оте мьнаме иро оте мьнаме иро ле иро сееоро а ле иро мьнобу г тий домтои онмежетаи ае нымо ий доскоятто хежоскто нмалоску иро ий бсирже ныме дхаякте бси вихкы иро пехегкихе гокохый оте шлтебеме номучи а номучи ныма жмя тии тибыхелаео еамы
#
# New best llh:  -2625.5715842090676
# Best decryption:  докхинтоску замта шбилавиттея бымжохоблитаие ныле кег салуте а шслобая замта ныла кег тобы а дхаякты вко етте вшбскбобеле синя тидхоскакилуто свесклабоь вие нолучи оте шмтебеле бхотсгоро кие нолучи оте льнале иро оте льнале иро ме иро сееоро а ме иро льнобу г тий долтои онлежетаи ае ныло ий доскоятто хежоскто нламоску иро ий бсирже ныле дхаякте бси вихкы иро пехегкихе гокохый оте шмтебеле нолучи а нолучи ныла жля тии тибыхемаео еалы
#
# New best llh:  -2570.560560705711
# Best decryption:  докринтоску замта шбилавиттея бымжороблитаие ныле кег салуте а шслобая замта ныла кег тобы а драякты вко етте вшбскбобеле синя тидроскакилуто свесклабоь вие нолучи оте шмтебеле бротсгохо кие нолучи оте льнале ихо оте льнале ихо ме ихо сееохо а ме ихо льнобу г тий долтои онлежетаи ае ныло ий доскоятто режоскто нламоску ихо ий бсихже ныле драякте бси виркы ихо перегкире гокорый оте шмтебеле нолучи а нолучи ныла жля тии тибыремаео еалы
#
# New best llh:  -2566.546578443312
# Best decryption:  докринтоску замта шбилавиттея бымуороблитаие ныле кег салуте а шслобая замта ныла кег тобы а драякты вко етте вшбскбобеле синя тидроскакилуто свесклабоь вие нолучи оте шмтебеле бротсгохо кие нолучи оте льнале ихо оте льнале ихо ме ихо сееохо а ме ихо льнобу г тий долтои онлеуетаи ае ныло ий доскоятто реуоскто нламоску ихо ий бсихуе ныле драякте бси виркы ихо перегкире гокорый оте шмтебеле нолучи а нолучи ныла уля тии тибыремаео еалы
#
# New best llh:  -2565.3798007565433
# Best decryption:  докринтоску замта шбилавиттея бымгороблитаие ныле кеу салуте а шслобая замта ныла кеу тобы а драякты вко етте вшбскбобеле синя тидроскакилуто свесклабоь вие нолучи оте шмтебеле бротсуохо кие нолучи оте льнале ихо оте льнале ихо ме ихо сееохо а ме ихо льнобу у тий долтои онлегетаи ае ныло ий доскоятто регоскто нламоску ихо ий бсихге ныле драякте бси виркы ихо переукире уокорый оте шмтебеле нолучи а нолучи ныла гля тии тибыремаео еалы
#
# New best llh:  -2544.262630032261
# Best decryption:  докринтоску шамта збилавиттея бымгороблитаие ныле кеу салуте а зслобая шамта ныла кеу тобы а драякты вко етте взбскбобеле синя тидроскакилуто свесклабоь вие нолучи оте змтебеле бротсуохо кие нолучи оте льнале ихо оте льнале ихо ме ихо сееохо а ме ихо льнобу у тий долтои онлегетаи ае ныло ий доскоятто регоскто нламоску ихо ий бсихге ныле драякте бси виркы ихо переукире уокорый оте змтебеле нолучи а нолучи ныла гля тии тибыремаео еалы
#
# New best llh:  -2540.7093293540875
# Best decryption:  докринтоску памта збилавиттея бымгороблитаие ныле кеу салуте а зслобая памта ныла кеу тобы а драякты вко етте взбскбобеле синя тидроскакилуто свесклабоь вие нолучи оте змтебеле бротсуохо кие нолучи оте льнале ихо оте льнале ихо ме ихо сееохо а ме ихо льнобу у тий долтои онлегетаи ае ныло ий доскоятто регоскто нламоску ихо ий бсихге ныле драякте бси виркы ихо шереукире уокорый оте змтебеле нолучи а нолучи ныла гля тии тибыремаео еалы
#
# New best llh:  -2532.213797439122
# Best decryption:  докринтоску пачта збилавиттея бычгороблитаие ныле кеу салуте а зслобая пачта ныла кеу тобы а драякты вко етте взбскбобеле синя тидроскакилуто свесклабоь вие нолуми оте зчтебеле бротсуохо кие нолуми оте льнале ихо оте льнале ихо че ихо сееохо а че ихо льнобу у тий долтои онлегетаи ае ныло ий доскоятто регоскто нлачоску ихо ий бсихге ныле драякте бси виркы ихо шереукире уокорый оте зчтебеле нолуми а нолуми ныла гля тии тибыречаео еалы
#
# New best llh:  -2515.703660641841
# Best decryption:  докринтоску пачта убилавиттея бычгороблитаие ныле кез салуте а услобая пачта ныла кез тобы а драякты вко етте вубскбобеле синя тидроскакилуто свесклабоь вие нолуми оте учтебеле бротсзохо кие нолуми оте льнале ихо оте льнале ихо че ихо сееохо а че ихо льнобу з тий долтои онлегетаи ае ныло ий доскоятто регоскто нлачоску ихо ий бсихге ныле драякте бси виркы ихо шерезкире зокорый оте учтебеле нолуми а нолуми ныла гля тии тибыречаео еалы
#
# New best llh:  -2506.688277401278
# Best decryption:  докритноску пачна убилавиннея бычгороблинаие тыле кез салуне а услобая пачна тыла кез нобы а драякны вко енне вубскбобеле ситя нидроскакилуно свесклабоь вие толуми оне учнебеле бронсзохо кие толуми оне льтале ихо оне льтале ихо че ихо сееохо а че ихо льтобу з ний долнои отлегенаи ае тыло ий доскоянно регоскно тлачоску ихо ий бсихге тыле драякне бси виркы ихо церезкире зокорый оне учнебеле толуми а толуми тыла гля нии нибыречаео еалы
#
# New best llh:  -2504.1422900149014
# Best decryption:  докритноску паена убилавиннея быегороблинаич тыле кез салуне а услобая паена тыла кез нобы а драякны вко енне вубскбобеле ситя нидроскакилуно свесклабоь вич толуми оне уенебеле бронсзохо кич толуми оне льтале ихо оне льтале ихо ее ихо сечохо а ее ихо льтобу з ний долнои отлегенаи ач тыло ий доскоянно регоскно тлаеоску ихо ий бсихге тыле драякне бси виркы ихо церезкире зокорый оне уенебеле толуми а толуми тыла гля нии нибырееачо чалы
#
# New best llh:  -2500.0681757716216
# Best decryption:  докритноску паена убилавиннея быегороблинаич тыле кез салуне а услобая паена тыла кез нобы а драякны вко енне вубскбобеле ситя нидроскакилуно свесклабоь вич толуми оне уенебеле бронсзохо кич толуми оне льтале ихо оне льтале ихо ее ихо сечохо а ее ихо льтобу з ний долнои отлегенаи ач тыло ий доскоянно регоскно тлаеоску ихо ий бсихге тыле драякне бси виркы ихо жерезкире зокорый оне уенебеле толуми а толуми тыла гля нии нибырееачо чалы
#
# New best llh:  -2487.785784876126
# Best decryption:  докритноску пазна убилавиннея бызгороблинаич тыле кее салуне а услобая пазна тыла кее нобы а драякны вко енне вубскбобеле ситя нидроскакилуно свесклабоь вич толуми оне узнебеле бронсеохо кич толуми оне льтале ихо оне льтале ихо зе ихо сечохо а зе ихо льтобу е ний долнои отлегенаи ач тыло ий доскоянно регоскно тлазоску ихо ий бсихге тыле драякне бси виркы ихо жереекире еокорый оне узнебеле толуми а толуми тыла гля нии нибырезачо чалы
#
# New best llh:  -2469.7725241421
# Best decryption:  докритноску пазна убилавиннея бызгороблинаим тыле кее салуне а услобая пазна тыла кее нобы а драякны вко енне вубскбобеле ситя нидроскакилуно свесклабоь вим толучи оне узнебеле бронсеохо ким толучи оне льтале ихо оне льтале ихо зе ихо семохо а зе ихо льтобу е ний долнои отлегенаи ам тыло ий доскоянно регоскно тлазоску ихо ий бсихге тыле драякне бси виркы ихо жереекире еокорый оне узнебеле толучи а толучи тыла гля нии нибырезамо малы
#
# New best llh:  -2447.2022309432973
# Best decryption:  докритноску пазна увилабиннея вызгоровлинаим тыле кее салуне а условая пазна тыла кее новы а драякны бко енне бувсквовеле ситя нидроскакилуно сбесклавоь бим толучи оне узневеле вронсеохо ким толучи оне льтале ихо оне льтале ихо зе ихо семохо а зе ихо льтову е ний долнои отлегенаи ам тыло ий доскоянно регоскно тлазоску ихо ий всихге тыле драякне вси биркы ихо жереекире еокорый оне узневеле толучи а толучи тыла гля нии нивырезамо малы
#
# New best llh:  -2443.9009933276852
# Best decryption:  докретноску пазна увелабенния вызгоровленаем тыли кие салуни а условая пазна тыла кие новы а драякны бко инни бувсквовили сетя недроскакелуно сбисклавоь бем толуше они узнивили вронсеохо кем толуше они льтали ехо они льтали ехо зи ехо симохо а зи ехо льтову е ней долное отлигинае ам тыло ей доскоянно ригоскно тлазоску ехо ей всехги тыли драякни все беркы ехо жириекери еокорый они узнивили толуше а толуше тыла гля нее невыризамо малы
#
# New best llh:  -2442.54045444838
# Best decryption:  докребноску пазна увелатенния вызгоровленаем были кие салуни а условая пазна была кие новы а драякны тко инни тувсквовили себя недроскакелуно стисклавоь тем болуше они узнивили вронсеохо кем болуше они льбали ехо они льбали ехо зи ехо симохо а зи ехо льбову е ней долное облигинае ам было ей доскоянно ригоскно блазоску ехо ей всехги были драякни все теркы ехо жириекери еокорый они узнивили болуше а болуше была гля нее невыризамо малы
#
# New best llh:  -2416.1082710814258
# Best decryption:  дотребносту пазна увелакенния вызгоровленаем были тие салуни а условая пазна была тие новы а драятны кто инни кувствовили себя недростателуно скистлавоь кем болуше они узнивили вронсеохо тем болуше они льбали ехо они льбали ехо зи ехо симохо а зи ехо льбову е ней долное облигинае ам было ей достоянно ригостно блазосту ехо ей всехги были драятни все керты ехо жириетери еоторый они узнивили болуше а болуше была гля нее невыризамо малы
#
# New best llh:  -2414.5410284796426
# Best decryption:  дотребносту казна увелапенния вызгоровленаем были тие салуни а условая казна была тие новы а драятны пто инни пувствовили себя недростателуно спистлавоь пем болуше они узнивили вронсеохо тем болуше они льбали ехо они льбали ехо зи ехо симохо а зи ехо льбову е ней долное облигинае ам было ей достоянно ригостно блазосту ехо ей всехги были драятни все перты ехо жириетери еоторый они узнивили болуше а болуше была гля нее невыризамо малы
#  15%|█▌        | 1519/10000 [00:00<00:02, 3732.70it/s]
# New best llh:  -2411.9216832609914
# Best decryption:  дотребносту казна увелаченния вызгоровленаем были тие салуни а условая казна была тие новы а драятны что инни чувствовили себя недростателуно счистлавоь чем болуше они узнивили вронсеохо тем болуше они льбали ехо они льбали ехо зи ехо симохо а зи ехо льбову е ней долное облигинае ам было ей достоянно ригостно блазосту ехо ей всехги были драятни все черты ехо жириетери еоторый они узнивили болуше а болуше была гля нее невыризамо малы
#
# New best llh:  -2401.994365623792
# Best decryption:  дотребносту хазна увелаченния вызгоровленаем были тие салуни а условая хазна была тие новы а драятны что инни чувствовили себя недростателуно счистлавоь чем болуше они узнивили вронсеоко тем болуше они льбали еко они льбали еко зи еко симоко а зи еко льбову е ней долное облигинае ам было ей достоянно ригостно блазосту еко ей всекги были драятни все черты еко жириетери еоторый они узнивили болуше а болуше была гля нее невыризамо малы
#
# New best llh:  -2386.3777052736814
# Best decryption:  дотребносту хазна увелаченния вызкоровленаем были тие салуни а условая хазна была тие новы а драятны что инни чувствовили себя недростателуно счистлавоь чем болуше они узнивили вронсеого тем болуше они льбали его они льбали его зи его симого а зи его льбову е ней долное обликинае ам было ей достоянно рикостно блазосту его ей всегки были драятни все черты его жириетери еоторый они узнивили болуше а болуше была кля нее невыризамо малы
#
# New best llh:  -2381.010230051381
# Best decryption:  котребносту хазна увелаченния выздоровленаем были тие салуни а условая хазна была тие новы а краятны что инни чувствовили себя некростателуно счистлавоь чем болуше они узнивили вронсеого тем болуше они льбали его они льбали его зи его симого а зи его льбову е ней колное облидинае ам было ей костоянно ридостно блазосту его ей всегди были краятни все черты его жириетери еоторый они узнивили болуше а болуше была для нее невыризамо малы
#
# New best llh:  -2380.431746500473
# Best decryption:  котребносту хазна увелаченнея выздоровленаем быле теи салуне а условая хазна была теи новы а краятны что енне чувствовеле себя некростателуно счестлавоь чем болуше оне узневеле вронсиого тем болуше оне льбале его оне льбале его зе его семого а зе его льбову и ней колное обледенае ам было ей костоянно редостно блазосту его ей всегде быле краятне все черты его жереитере иоторый оне узневеле болуше а болуше была для нее невырезамо малы
#
# New best llh:  -2363.6839361183715
# Best decryption:  котребность хазна увелаченнея выздоровленаем быле теи сальне а условая хазна была теи новы а краятны что енне чувствовеле себя некростательно счестлавоу чем больше оне узневеле вронсиого тем больше оне лубале его оне лубале его зе его семого а зе его лубовь и ней колное обледенае ам было ей костоянно редостно блазость его ей всегде быле краятне все черты его жереитере иоторый оне узневеле больше а больше была для нее невырезамо малы
#
# New best llh:  -2358.56729550102
# Best decryption:  котребность пазна увелаченнея выздоровленаем быле теи сальне а условая пазна была теи новы а краятны что енне чувствовеле себя некростательно счестлавоу чем больше оне узневеле вронсиого тем больше оне лубале его оне лубале его зе его семого а зе его лубовь и ней колное обледенае ам было ей костоянно редостно блазость его ей всегде быле краятне все черты его жереитере иоторый оне узневеле больше а больше была для нее невырезамо малы
#
# New best llh:  -2345.101582651889
# Best decryption:  котребность пизни увеличенная выздоровлением была тае сильна и условия пизни были тае новы и криятны что анна чувствовала себя некростительно счастливоу чем больше она узнавала вронсеого тем больше она лубила его она лубила его за его самого и за его лубовь е ней колное обладание им было ей костоянно радостно близость его ей всегда была криятна все черты его жараетера еоторый она узнавала больше и больше были для нее невыразимо милы
#  34%|███▍      | 3435/10000 [00:00<00:01, 3839.58it/s]
# New best llh:  -2338.365540769694
# Best decryption:  потребность кизни увеличенная выздоровлением была тае сильна и условия кизни были тае новы и приятны что анна чувствовала себя непростительно счастливоу чем больше она узнавала вронсеого тем больше она лубила его она лубила его за его самого и за его лубовь е ней полное обладание им было ей постоянно радостно близость его ей всегда была приятна все черты его хараетера еоторый она узнавала больше и больше были для нее невыразимо милы
#
# New best llh:  -2337.333185527743
# Best decryption:  потребность кизни увеличенная выздоровлением была тае сильна и условия кизни были тае новы и приятны что анна чувствовала себя непростительно счастливоу чем больше она узнавала вронсеого тем больше она лубила его она лубила его за его самого и за его лубовь е ней полное обладание им было ей постоянно радостно близость его ей всегда была приятна все черты его жараетера еоторый она узнавала больше и больше были для нее невыразимо милы
# 100%|██████████| 10000/10000 [00:02<00:00, 3894.09it/s]
# New best llh:  -2335.748774172902
# Best decryption:  потребносте жизни увеличенная выздоровлением была так силена и условия жизни были так новы и приятны что анна чувствовала себя непростителено счастливоу чем болеше она узнавала вронского тем болеше она лубила его она лубила его за его самого и за его лубове к ней полное обладание им было ей постоянно радостно близосте его ей всегда была приятна все черты его ьарактера который она узнавала болеше и болеше были для нее невыразимо милы
#
# New best llh:  -2322.197432873177
# Best decryption:  потребносте жизни увеличенная выздоровлением была так силена и условия жизни были так новы и приятны что анна чувствовала себя непростителено счастливоу чем болеше она узнавала вронского тем болеше она лубила его она лубила его за его самого и за его лубове к ней полное обладание им было ей постоянно радостно близосте его ей всегда была приятна все черты его характера который она узнавала болеше и болеше были для нее невыразимо милы
#
#
# Best decryption:
#  потребносте жизни увеличенная выздоровлением была так силена и условия жизни были так новы и приятны что анна чувствовала себя непростителено счастливоу чем болеше она узнавала вронского тем болеше она лубила его она лубила его за его самого и за его лубове к ней полное обладание им было ей постоянно радостно близосте его ей всегда была приятна все черты его характера который она узнавала болеше и болеше были для нее невыразимо милы
# Accuracy:  0.8181818181818182

# %% [markdown]
# Получили очень высокую точность (выше, чем я ожидал) и практически идеально читаемый текст.

# %% [markdown]
# ## Часть 4.

# %% [markdown]
# Расшифруйте сообщение:

# %%
test_cipher_text = 'დჳჵჂႨშႼႨშჂხჂჲდႨსႹႭჾႣჵისႼჰႨჂჵჂႨႲႹႧჲჂႨსႹႭჾႣჵისႼჰႨჲდႩჳჲႨჇႨႠჲႹქႹႨჳႹႹჱჶდსჂႽႨႩႹჲႹႭႼჰႨჵდქႩႹႨႲႭႹႧჂჲႣჲიႨჳႩႹႭდდႨშჳდქႹႨშႼႨშჳდႨჳხდჵႣჵჂႨႲႭႣშჂჵისႹႨჂႨႲႹჵჇႧჂჲდႨჾႣႩჳჂჾႣჵისႼჰႨჱႣჵჵႨეႣႨႲႹჳჵდხსდდႨႧდჲშდႭჲႹდႨეႣხႣსჂდႨႩჇႭჳႣႨႾႹჲႽႨႩႹსდႧსႹႨႽႨსჂႧდქႹႨსდႨႹჱდჶႣნ'

# %% [markdown]
# Без потери общности, перейдем от имеющихся символов к алфавиту русского языка (чисто техническое соображение):

# %%
syms_to_ru = {}
for sym in test_cipher_text:
    if sym not in syms_to_ru.keys():
        syms_to_ru[sym] = alphabet[len(syms_to_ru)]

test_cipher_text = "".join([syms_to_ru[sym] for sym in test_cipher_text])
test_cipher_text
# Out:
# ' абвгдегдвжвз гийклмбниеогвбвгпйрзвгийклмбниеогз сазгтгузйфйгаййхц ивчгсйзйкеогб фсйгпкйрвзмзнгасйк  гда фйгдегда гаж бмбвгпкмдвбнийгвгпйбтрвз глмсавлмбниеогхмббгшмгпйаб жи  гр зд кзй гшмжмив гсткамгщйзчгсйи рийгчгивр фйги гйх цмъ'

# %% [markdown]
# В качестве начального приближения возьмем перестановку, основанную на частотах встречаемости символов:

# %%
dec_test = NgramDecryptor(ngram_size=1)
dec_test.fit(test_cipher_text)
decrypt_substitution = extend_substitution_to_full(dec_test.decrypt_substitution, etalon_freqs)

# %%
best_substitution = mcmc_sampling(test_cipher_text, decrypt_substitution, n_steps=20000)
print("\nBest decryption: \n", decrypt_substitution_cipher(test_cipher_text, best_substitution))
# Out:
#   3%|▎         | 589/20000 [00:00<00:03, 5860.76it/s]
# New best llh:  -1511.211634967785
# Best decryption:  елна рд раяасе иовьтнуиды ана помса иовьтнуиды секлс б йсого лоочжеиаз косовды негко пвомастсу лковее рлего рд рле ляентна пвтрануио а понбмасе ьтклаьтнуиды чтнн шт полнеяиее месревсое штятиае кбвлт хосз коиемио з иамего ие очежтю
#
# New best llh:  -1495.5580873788285
# Best decryption:  елна рд раяасе иовьтнбиды ана помса иовьтнбиды секлс у йсого лоочжеиаз косовды негко пвомастсб лковее рлего рд рле ляентна пвтранбио а понумасе ьтклаьтнбиды чтнн шт полнеяиее месревсое штятиае кувлт хосз коиемио з иамего ие очежтю
#
# New best llh:  -1487.0427906217942
# Best decryption:  елна рд разасе иовьтнбиды ана помса иовьтнбиды секлс у йсого лоочжеиая косовды негко пвомастсб лковее рлего рд рле лзентна пвтранбио а понумасе ьтклаьтнбиды чтнн шт полнезиее месревсое штзтиае кувлт хося коиемио я иамего ие очежтю
#
# New best llh:  -1480.035291691983
# Best decryption:  елна рд разасе иовьтнбиды ана помса иовьтнбиды секлс у ясого лоочжеиая косовды негко пвомастсб лковее рлего рд рле лзентна пвтранбио а понумасе ьтклаьтнбиды чтнн шт полнезиее месревсое штзтиае кувлт хося коиемио я иамего ие очежтю
#
# New best llh:  -1476.3747080048615
# Best decryption:  една рл разасе иовьтнбилы ана помса иовьтнбилы секдс у ясого доочжеиая косовлы негко пвомастсб дковее рдего рл рде дзентна пвтранбио а понумасе ьткдаьтнбилы чтнн шт поднезиее месревсое штзтиае кувдт хося коиемио я иамего ие очежтю
#
# New best llh:  -1473.4932009155232
# Best decryption:  ебна рл разасе иовьтндилы ана помса иовьтндилы секбс у ясого боочжеиая косовлы негко пвомастсд бковее рбего рл рбе бзентна пвтрандио а понумасе ьткбаьтндилы чтнн шт побнезиее месревсое штзтиае кувбт хося коиемио я иамего ие очежтю
#
# New best llh:  -1470.3947449635948
# Best decryption:  ебна рл разасе иовьтндилы ана помса иовьтндилы секбс у ясого боочшеиая косовлы негко пвомастсд бковее рбего рл рбе бзентна пвтрандио а понумасе ьткбаьтндилы чтнн жт побнезиее месревсое жтзтиае кувбт хося коиемио я иамего ие очештю
#
# New best llh:  -1446.5651019284744
# Best decryption:  ебна ил иазасе ровьтндрлы ана помса ровьтндрлы секбс у ясого боочшерая косовлы негко пвомастсд бковее ибего ил ибе бзентна пвтиандро а понумасе ьткбаьтндрлы чтнн жт побнезрее месиевсое жтзтрае кувбт хося коремро я рамего ре очештю
#
# New best llh:  -1435.7316992520432
# Best decryption:  езна ил иабасе ровьтндрлы ана помса ровьтндрлы секзс у ясого зоочшерая косовлы негко пвомастсд зковее изего ил изе збентна пвтиандро а понумасе ьткзаьтндрлы чтнн жт познебрее месиевсое жтбтрае кувзт хося коремро я рамего ре очештю
#
# New best llh:  -1432.843633608689
# Best decryption:  езна ил иабасе ровьтндрлю ана помса ровьтндрлю секзс у ясого зоочшерая косовлю негко пвомастсд зковее изего ил изе збентна пвтиандро а понумасе ьткзаьтндрлю чтнн жт познебрее месиевсое жтбтрае кувзт хося коремро я рамего ре очешты
#
# New best llh:  -1431.8255256962452
# Best decryption:  езна ил иапасе ровьтндрлю ана бомса ровьтндрлю секзс у ясого зоочшерая косовлю негко бвомастсд зковее изего ил изе зпентна бвтиандро а бонумасе ьткзаьтндрлю чтнн жт бознепрее месиевсое жтптрае кувзт хося коремро я рамего ре очешты
#
# New best llh:  -1422.2979228680178
# Best decryption:  езна ил иапасе ровьтндрль ана бомса ровьтндрль секзс у ясого зоочшерая косовль негко бвомастсд зковее изего ил изе зпентна бвтиандро а бонумасе ьткзаьтндрль чтнн жт бознепрее месиевсое жтптрае кувзт хося коремро я рамего ре очешты
#
# New best llh:  -1419.8450661151671
# Best decryption:  езна ил иапасе ровьтндрль ана бомса ровьтндрль секзс у ясого зоочшерая косовль негко бвомастсд зковее изего ил изе зпентна бвтиандро а бонумасе ьткзаьтндрль чтнн ют бознепрее месиевсое ютптрае кувзт хося коремро я рамего ре очешты
#
# New best llh:  -1418.3846685109224
# Best decryption:  езна ил иапасе ровчтндрль ана бомса ровчтндрль секзс у ясого зооьшерая косовль негко бвомастсд зковее изего ил изе зпентна бвтиандро а бонумасе чткзачтндрль ьтнн ют бознепрее месиевсое ютптрае кувзт хося коремро я рамего ре оьешты
#
# New best llh:  -1418.0653006599582
# Best decryption:  езна ил иаьасе ровчтндрль ана бомса ровчтндрль секзс у ясого зоопшерая косовль негко бвомастсд зковее изего ил изе зьентна бвтиандро а бонумасе чткзачтндрль птнн ют бознеьрее месиевсое ютьтрае кувзт хося коремро я рамего ре опешты
#
# New best llh:  -1412.9788780945164
# Best decryption:  елна из иаьасе ровчтндрзь ана бомса ровчтндрзь секлс у ясого лоопшерая косовзь негко бвомастсд лковее илего из иле льентна бвтиандро а бонумасе чтклачтндрзь птнн ют болнеьрее месиевсое ютьтрае кувлт хося коремро я рамего ре опешты
#
# New best llh:  -1401.460029328753
# Best decryption:  есна из иаьале ровчтндрзь ана бомла ровчтндрзь лексл у ялого соопшерая коловзь негко бвомалтлд сковее исего из исе сьентна бвтиандро а бонумале чтксачтндрзь птнн ют боснеьрее мелиевлое ютьтрае кувст холя коремро я рамего ре опешты
#
# New best llh:  -1400.1655330760198
# Best decryption:  есна из иаьале ровчтндрзы ана бомла ровчтндрзы лексл у ялого соопшерая коловзы негко бвомалтлд сковее исего из исе сьентна бвтиандро а бонумале чтксачтндрзы птнн ют боснеьрее мелиевлое ютьтрае кувст холя коремро я рамего ре опешть
#
# New best llh:  -1390.6793115262224
# Best decryption:  есна из иадале ровчтньрзы ана бомла ровчтньрзы лексл у ялого соопшерая коловзы негко бвомалтль сковее исего из исе сдентна бвтианьро а бонумале чтксачтньрзы птнн ют боснедрее мелиевлое ютдтрае кувст холя коремро я рамего ре опешть
#
# New best llh:  -1386.6449096204187
# Best decryption:  есна из иадале ровчтнюрзы ана бомла ровчтнюрзы лексл у ялого соопшерая коловзы негко бвомалтлю сковее исего из исе сдентна бвтианюро а бонумале чтксачтнюрзы птнн ют боснедрее мелиевлое ютдтрае кувст холя коремро я рамего ре опешть
#
# New best llh:  -1380.794014980457
# Best decryption:  есна им иадале ровчтнюрмы ана бозла ровчтнюрмы лексл у ялого соопшерая коловмы негко бвозалтлю сковее исего им исе сдентна бвтианюро а бонузале чтксачтнюрмы птнн ют боснедрее зелиевлое ютдтрае кувст холя корезро я разего ре опешть
#
# New best llh:  -1361.2000061768822
# Best decryption:  есна им иадале ровчтнырмы ана бозла ровчтнырмы лексл у ялого соопшерая коловмы негко бвозалтлы сковее исего им исе сдентна бвтианыро а бонузале чтксачтнырмы птнн ют боснедрее зелиевлое ютдтрае кувст холя корезро я разего ре опешть
#
# New best llh:  -1357.6602801230742
# Best decryption:  есна им иадале ровчтнырмы ана бозла ровчтнырмы лексл у юлого соопшерая коловмы негко бвозалтлы сковее исего им исе сдентна бвтианыро а бонузале чтксачтнырмы птнн ят боснедрее зелиевлое ятдтрае кувст холя корезро я разего ре опешть
#
# New best llh:  -1355.8369762888044
# Best decryption:  есна тм тадале ровчинырмы ана бозла ровчинырмы лексл у юлого соопшерая коловмы негко бвозалилы сковее тсего тм тсе сденина бвитаныро а бонузале чиксачинырмы пинн яи боснедрее зелтевлое яидирае кувси холя корезро я разего ре опешиь
#
# New best llh:  -1350.9480940449346
# Best decryption:  есна тм тадале ровчинырмы ана бозла ровчинырмы лексл у йлого соопшерая коловмы негко бвозалилы сковее тсего тм тсе сденина бвитаныро а бонузале чиксачинырмы пинн яи боснедрее зелтевлое яидирае кувси холя корезро я разего ре опешию
#
# New best llh:  -1350.2717617118317
# Best decryption:  есна тм тадале ровзинырмы ана бочла ровзинырмы лексл у йлого соопшерая коловмы негко бвочалилы сковее тсего тм тсе сденина бвитаныро а бонучале зиксазинырмы пинн яи боснедрее челтевлое яидирае кувси холя коречро я рачего ре опешию
#
# New best llh:  -1349.359955838673
# Best decryption:  есна вм вадале ротчинырмы ана бозла ротчинырмы лексл у йлого соопшерая колотмы негко бтозалилы скотее всего вм все сденина бтиваныро а бонузале чиксачинырмы пинн яи боснедрее зелветлое яидирае кутси холя корезро я разего ре опешию
#
# New best llh:  -1347.070282686725
# Best decryption:  есна вм вадале ротчинырмы ана бозла ротчинырмы лексл у юлого соопшерая колотмы негко бтозалилы скотее всего вм все сденина бтиваныро а бонузале чиксачинырмы пинн яи боснедрее зелветлое яидирае кутси холя корезро я разего ре опеший
#
# New best llh:  -1346.3924817293541
# Best decryption:  есна вм вадале ротчинырмы ана бопла ротчинырмы лексл у юлого соозшерая колотмы негко бтопалилы скотее всего вм все сденина бтиваныро а бонупале чиксачинырмы зинн яи боснедрее пелветлое яидирае кутси холя корепро я рапего ре озеший
#
# New best llh:  -1345.5853031474678
# Best decryption:  есна вм вапале ротчинырмы ана бозла ротчинырмы лексл у юлого соодшерая колотмы негко бтозалилы скотее всего вм все спенина бтиваныро а бонузале чиксачинырмы динн яи боснепрее зелветлое яипирае кутси холя корезро я разего ре одеший
#
# New best llh:  -1345.4127877199023
# Best decryption:  евна см сапале ротчинырмы ана бозла ротчинырмы леквл у юлого воодшерая колотмы негко бтозалилы вкотее свего см све впенина бтисаныро а бонузале чиквачинырмы динн яи бовнепрее зелсетлое яипирае кутви холя корезро я разего ре одеший
#
# New best llh:  -1339.2780453278872
# Best decryption:  евна см сазале ротчинырмы ана бопла ротчинырмы леквл у юлого воодшерая колотмы негко бтопалилы вкотее свего см све взенина бтисаныро а бонупале чиквачинырмы динн яи бовнезрее пелсетлое яизирае кутви холя корепро я рапего ре одеший
#
# New best llh:  -1331.7614821650855
# Best decryption:  евна см сазале ротчинырмы ана бопла ротчинырмы леквл у юлого воодшерая колотмы негко бтопалилы вкотее свего см све взенина бтисаныро а бонупале чиквачинырмы динн жи бовнезрее пелсетлое жизирае кутви холя корепро я рапего ре одеший
#
# New best llh:  -1320.7583465903579
# Best decryption:  евна сы сазале ротчинырым ана бопла ротчинырым леквл у юлого воодшерая колотым негко бтопалилы вкотее свего сы све взенина бтисаныро а бонупале чиквачинырым динн жи бовнезрее пелсетлое жизирае кутви холя корепро я рапего ре одеший
#
# New best llh:  -1320.0889340501615
# Best decryption:  евна ть тазале росчинырьм ана бопла росчинырьм леквл у юлого воодшерая колосьм негко бсопалилы вкосее твего ть тве взенина бситаныро а бонупале чиквачинырьм динн жи бовнезрее пелтеслое жизирае кусви холя корепро я рапего ре одеший
#
# New best llh:  -1312.5794372103135
# Best decryption:  евна ть тазале росчинырью ана бопла росчинырью леквл у ялого воодшерая колосью негко бсопалилы вкосее твего ть тве взенина бситаныро а бонупале чиквачинырью динн жи бовнезрее пелтеслое жизирае кусви холя корепро я рапего ре одеший
#
# New best llh:  -1310.1292331173834
# Best decryption:  евна ть тазале росчинырью ана бодла росчинырью леквл у ялого воопшерая колосью негко бсодалилы вкосее твего ть тве взенина бситаныро а бонудале чиквачинырью пинн жи бовнезрее делтеслое жизирае кусви холя коредро я радего ре опеший
#
# New best llh:  -1307.407382858972
# Best decryption:  евна ть тамале росчинырью ана бодла росчинырью леквл у ялого воопшерая колосью негко бсодалилы вкосее твего ть тве вменина бситаныро а бонудале чиквачинырью пинн жи бовнемрее делтеслое жимирае кусви холя коредро я радего ре опеший
#
# New best llh:  -1307.1155468729046
# Best decryption:  евна ть тамале росчинырью ана бодла росчинырью леквл у ялого воопшерая колосью негко бсодалилы вкосее твего ть тве вменина бситаныро а бонудале чиквачинырью пинн жи бовнемрее делтеслое жимирае кусви холя коредро я радего ре опешиз
#
# New best llh:  -1306.7118653418445
# Best decryption:  есна ть тамале ровчинырью ана бодла ровчинырью лексл у ялого соопшерая коловью негко бводалилы сковее тсего ть тсе сменина бвитаныро а бонудале чиксачинырью пинн жи боснемрее делтевлое жимирае кувси холя коредро я радего ре опешиз
#
# New best llh:  -1302.7734099226932
# Best decryption:  есна ть тамале ровпинырью ана бодла ровпинырью лексл у ялого соочшерая коловью негко бводалилы сковее тсего ть тсе сменина бвитаныро а бонудале пиксапинырью чинн жи боснемрее делтевлое жимирае кувси холя коредро я радего ре очешиз
#  13%|█▎        | 2533/20000 [00:00<00:02, 6266.52it/s]
# New best llh:  -1295.4304541943325
# Best decryption:  есна вь вамале торпинытью ана бодла торпинытью лексл у ялого соочшетая колорью негко бродалилы скорее всего вь все сменина бриваныто а бонудале пиксапинытью чинн жи боснемтее делверлое жимитае курси холя котедто я тадего те очешиз
#
# New best llh:  -1291.9514804042897
# Best decryption:  есна ль лачаве торминытью ана бодва торминытью вексв у явого соопшетая коворью негко бродавивы скорее лсего ль лсе сченина бриланыто а бонудаве миксаминытью пинн жи боснечтее девлервое жичитае курси ховя котедто я тадего те опешиз
#
# New best llh:  -1290.2210058605872
# Best decryption:  есни ль личиве торманытью ини бодви торманытью вексв у явого соопшетия коворью негко бродивавы скорее лсего ль лсе сченани бралиныто и бонудиве максиманытью панн жа боснечтее девлервое жачатие курса ховя котедто я тидего те опешаз
#
# New best llh:  -1289.6117091390463
# Best decryption:  есни ль личиве торманытью ини бодви торманытью вексв у явого соожшетия коворью негко бродивавы скорее лсего ль лсе сченани бралиныто и бонудиве максиманытью жанн па боснечтее девлервое пачатие курса ховя котедто я тидего те ожешаз
#
# New best llh:  -1289.0019345433675
# Best decryption:  если нь ничиве торжалытью или бодви торжалытью вексв у явого соомшетия коворью легко бродивавы скорее нсего нь нсе счелали бранилыто и болудиве жаксижалытью малл па бослечтее девнервое пачатие курса ховя котедто я тидего те омешаз
#
# New best llh:  -1288.6955940046255
# Best decryption:  есни ль личиве торжанытью ини бодви торжанытью вексв у явого соомшетия коворью негко бродивавы скорее лсего ль лсе сченани бралиныто и бонудиве жаксижанытью манн па боснечтее девлервое пачатие курса ховя котедто я тидего те омешаз
#
# New best llh:  -1280.9874983467532
# Best decryption:  есни вь вичиле торзанытью ини помли торзанытью лексл у ялого соодшетия колорью негко промилалы скорее всего вь все сченани правиныто и понумиле заксизанытью данн ха поснечтее мелверлое хачатие курса боля котемто я тимего те одешаж
#
#  19%|█▉        | 3853/20000 [00:00<00:02, 6413.74it/s] -1280.1163428537352
# Best decryption:  евни сь симиле торбанытью ини почли торбанытью леквл у ялого воодшетия колорью негко прочилалы вкорее свего сь све вменани прасиныто и понучиле баквибанытью данн за повнемтее челсерлое заматие курва холя котечто я тичего те одешаю
#
# New best llh:  -1277.8271092405496
# Best decryption:  евли сь симине торбалытью или почни торбалытью неквн у яного воодшетия конорью легко прочинаны вкорее свего сь све вмелали прасилыто и получине баквибалытью далл за повлемтее ченсерное заматие курва хоня котечто я тичего те одешаю
#
# New best llh:  -1274.3756529910236
# Best decryption:  евли сь симине тордалытью или почни тордалытью неквн у яного вообшетия конорью легко прочинаны вкорее свего сь све вмелали прасилыто и получине даквидалытью балл за повлемтее ченсерное заматие курва хоня котечто я тичего те обешаю
#
# New best llh:  -1273.9020239654049
# Best decryption:  евли сь симине тордалытью или почни тордалытью неквн у яного вообжетия конорью легко прочинаны вкорее свего сь све вмелали прасилыто и получине даквидалытью балл за повлемтее ченсерное заматие курва хоня котечто я тичего те обежаю
#
# New best llh:  -1273.6330621810857
# Best decryption:  евли сь симине тордалытью или почни тордалытью неквн у яного воожбетия конорью легко прочинаны вкорее свего сь све вмелали прасилыто и получине даквидалытью жалл за повлемтее ченсерное заматие курва хоня котечто я тичего те ожебаю
#
# New best llh:  -1273.2493132869738
# Best decryption:  если вь вимине тордалытью или почни тордалытью нексн у яного соожбетия конорью легко прочинаны скорее всего вь все смелали правилыто и получине даксидалытью жалл за послемтее ченверное заматие курса хоня котечто я тичего те ожебаю
#
# New best llh:  -1270.044448383177
# Best decryption:  если вь вимите нордалынья или почти нордалынья текст у ютого сообжения которья легко прочитаты скорее всего вь все смелали правилыно и получите даксидалынья балл за послемнее четвертое замание курса хотя конечно я ничего не обежаю
#
# New best llh:  -1268.4110454578456
# Best decryption:  если вь вимите нордалынья или почти нордалынья текст у штого сообжения которья легко прочитаты скорее всего вь все смелали правилыно и получите даксидалынья балл за послемнее четвертое замание курса хотя конечно я ничего не обежаю
#  29%|██▉       | 5838/20000 [00:00<00:02, 6540.79it/s]
# New best llh:  -1267.2774639229513
# Best decryption:  есни вь вимите лорданылью ини почти лорданылью текст у ятого сообжелия которью негко прочитаты скорее всего вь все сменани правиныло и понучите даксиданылью банн за поснемлее четвертое замалие курса хотя колечло я личего ле обежаю
#
# New best llh:  -1267.0085021386324
# Best decryption:  есни вь вимите лорданылью ини почти лорданылью текст у ятого соожбелия которью негко прочитаты скорее всего вь все сменани правиныло и понучите даксиданылью жанн за поснемлее четвертое замалие курса хотя колечло я личего ле ожебаю
#
# New best llh:  -1265.993028952005
# Best decryption:  есни вь вимите лорданылью ини почти лорданылью текст у этого соожбелия которью негко прочитаты скорее всего вь все сменани правиныло и понучите даксиданылью жанн за поснемлее четвертое замалие курса хотя колечло я личего ле ожебаю
#
# New best llh:  -1261.0177748738126
# Best decryption:  есни вь вимите лорданылья ини почти лорданылья текст у этого соожбелия которья негко прочитаты скорее всего вь все сменани правиныло и понучите даксиданылья жанн за поснемлее четвертое замалие курса хотя колечло я личего ле ожебаю
#  39%|███▉      | 7810/20000 [00:01<00:01, 6504.98it/s]
# New best llh:  -1251.6224024422286
# Best decryption:  если вь вимите норжальнья или подти норжальнья текст у этого соочшения которья легко продитать скорее всего вь все смелали правильно и полудите жаксижальнья чалл за послемнее детвертое замание курса ботя конедно я нидего не очешай
#
# New best llh:  -1251.1609108273917
# Best decryption:  если вь вимите норжальнья или подти норжальнья текст у этого соочшения которья легко продитать скорее всего вь все смелали правильно и полудите жаксижальнья чалл за послемнее детвертое замание курса ботя конедно я нидего не очешаю
#
# New best llh:  -1251.1538271818197
# Best decryption:  если вь вимите норжальнья или подти норжальнья текст у этого соочшения которья легко продитать скорее всего вь все смелали правильно и полудите жаксижальнья чалл за послемнее детвертое замание курса ботя конедно я нидего не очешах
#  92%|█████████▏| 18368/20000 [00:02<00:00, 6425.71it/s]
# New best llh:  -1250.4090179817658
# Best decryption:  если вь вимите нордальнья или почти нордальнья текст у этого сообжения которья легко прочитать скорее всего вь все смелали правильно и получите даксидальнья балл за послемнее четвертое замание курса хотя конечно я ничего не обежаю
#
# New best llh:  -1250.1400561974467
# Best decryption:  если вь вимите нордальнья или почти нордальнья текст у этого соожбения которья легко прочитать скорее всего вь все смелали правильно и получите даксидальнья жалл за послемнее четвертое замание курса хотя конечно я ничего не ожебаю
# 100%|██████████| 20000/20000 [00:03<00:00, 6495.61it/s]
# Best decryption:
#  если вь вимите нордальнья или почти нордальнья текст у этого соожбения которья легко прочитать скорее всего вь все смелали правильно и получите даксидальнья жалл за послемнее четвертое замание курса хотя конечно я ничего не ожебаю

# %% [markdown]
# Текст практически нормальный, оставшиеся символы легко восстанавливаются при необходимости точного дешифрования.

# %% [markdown]
# ## Часть 5.

# %% [markdown]
# Бонус: а что если от биграмм перейти к триграммам (тройкам букв) или даже больше? Улучшатся ли результаты? Когда улучшатся, а когда нет? Чтобы ответить на этот вопрос эмпирически, уже может понадобиться погенерировать много тестовых перестановок и последить за метриками, глазами может быть и не видно.

# %% [markdown]
# Для примера проведем аналогичные п.2, 3 вычисления, основываясь на триграммах текста.

# %%
etalon_trigram_freqs = get_ngrams_freqs('AnnaKarenina.txt', ngram_size=3)
eps = 1e-6
etalon_log_freqs = {}
for i, j, k in product(alphabet, repeat=3):
    etalon_log_freqs[i + j + k] = np.log(etalon_trigram_freqs[i + j + k] + eps)

# %%
decrypt_substitution = extend_substitution_to_full(dec.decrypt_substitution, etalon_freqs)
best_substitution = mcmc_sampling(cipher_text, decrypt_substitution, etalon_log_freqs=etalon_log_freqs, ngram_size=3, n_steps=15000)
print("\nBest decryption: \n", decrypt_substitution_cipher(cipher_text, best_substitution))
print("Accuracy: ", decryption_quality(best_substitution, cipher_substitution))
# Out:
#   2%|▏         | 331/15000 [00:00<00:04, 3293.64it/s]
# New best llh:  -4330.609425096292
# Best decryption:  пекхинтескл зачта вмигадиттоя мычжехемгитаиь ныго коб саглто а всгемая зачта ныга коб темы а пхаякты дке отто двмскмемого синя типхескакиглте сдоскгамеш диь неглуи ето вчтомого мхетсбере киь неглуи ето гшнаго ире ето гшнаго ире чо ире соьере а чо ире гшнемл б тий пегтеи енгожотаи аь ныге ий пескеятте хожескте нгаческл ире ий мсиржо ныго пхаякто мси дихкы ире эохобкихо бекехый ето вчтомого неглуи а неглуи ныга жгя тии тимыхочаье ьагы
#
# New best llh:  -4318.7271317116
# Best decryption:  пекхинтескл задта вмигачиттоя мыджехемгитаиь ныго коб саглто а всгемая задта ныга коб темы а пхаякты чке отто чвмскмемого синя типхескакиглте счоскгамеш чиь неглуи ето вдтомого мхетсбере киь неглуи ето гшнаго ире ето гшнаго ире до ире соьере а до ире гшнемл б тий пегтеи енгожотаи аь ныге ий пескеятте хожескте нгадескл ире ий мсиржо ныго пхаякто мси чихкы ире эохобкихо бекехый ето вдтомого неглуи а неглуи ныга жгя тии тимыходаье ьагы
#
# New best llh:  -4285.663513760498
# Best decryption:  петхинкестл задка вмигачиккоя мыджехемгикаиь ныго тоб саглко а всгемая задка ныга тоб кемы а пхаяткы чте окко чвмстмемого синя кипхестатиглке счостгамеш чиь неглуи еко вдкомого мхексбере тиь неглуи еко гшнаго ире еко гшнаго ире до ире соьере а до ире гшнемл б кий пегкеи енгожокаи аь ныге ий пестеякке хожестке нгадестл ире ий мсиржо ныго пхаятко мси чихты ире эохобтихо бетехый еко вдкомого неглуи а неглуи ныга жгя кии кимыходаье ьагы
#
# New best llh:  -4209.905754433822
# Best decryption:  петхинкесть задка вмигачиккоя мыджехемгикаил ныго тоб сагько а всгемая задка ныга тоб кемы а пхаяткы чте окко чвмстмемого синя кипхестатигьке счостгамеш чил негьуи еко вдкомого мхексбере тил негьуи еко гшнаго ире еко гшнаго ире до ире солере а до ире гшнемь б кий пегкеи енгожокаи ал ныге ий пестеякке хожестке нгадесть ире ий мсиржо ныго пхаятко мси чихты ире эохобтихо бетехый еко вдкомого негьуи а негьуи ныга жгя кии кимыходале лагы
#
# New best llh:  -4187.598500676806
# Best decryption:  петхикнесть задна вмигачинноя мыджехемгинаил кыго тоб сагьно а всгемая задна кыга тоб немы а пхаятны чте онно чвмстмемого сикя нипхестатигьне счостгамеш чил кегьуи ено вдномого мхенсбере тил кегьуи ено гшкаго ире ено гшкаго ире до ире солере а до ире гшкемь б ний пегнеи екгожонаи ал кыге ий пестеянне хожестне кгадесть ире ий мсиржо кыго пхаятно мси чихты ире эохобтихо бетехый ено вдномого кегьуи а кегьуи кыга жгя нии нимыходале лагы
#
# New best llh:  -4149.003183059775
# Best decryption:  потхикность задна вмигачиннея мыджохомгинаил кыге теб сагьне а всгомая задна кыга теб номы а пхаятны что енне чвмстмомеге сикя нипхостатигьно счестгамош чил когьуи оне вднемеге мхонсборо тил когьуи оне гшкаге иро оне гшкаге иро де иро селоро а де иро гшкомь б ний погнои окгеженаи ал кыго ий постоянно хежостно кгадость иро ий мсирже кыге пхаятне мси чихты иро эехебтихе ботохый оне вднемеге когьуи а когьуи кыга жгя нии нимыхедало лагы
#
# New best llh:  -4138.503005097334
# Best decryption:  потхикность задна вмигачиннея мыджохомгинаил кыге теб сагьне а всгомая задна кыга теб номы а пхаятны что енне чвмстмомеге сикя нипхостатигьно счестгамош чил когьхи оне вднемеге мхонсборо тил когьхи оне гшкаге иро оне гшкаге иро де иро селоро а де иро гшкомь б ний погнои окгеженаи ал кыго ий постоянно хежостно кгадость иро ий мсирже кыге пхаятне мси чихты иро эехебтихе ботохый оне вднемеге когьхи а когьхи кыга жгя нии нимыхедало лагы
#
# New best llh:  -4112.284018587294
# Best decryption:  потхикность задна вгимачиннея гыджохогминаил кыме теб самьне а всмогая задна кыма теб ногы а пхаятны что енне чвгстгогеме сикя нипхостатимьно счестмагош чил комьхи оне вднегеме гхонсборо тил комьхи оне мшкаме иро оне мшкаме иро де иро селоро а де иро мшкогь б ний помнои окмеженаи ал кымо ий постоянно хежостно кмадость иро ий гсирже кыме пхаятне гси чихты иро эехебтихе ботохый оне вднегеме комьхи а комьхи кыма жмя нии нигыхедало ламы
#
# New best llh:  -4103.438744227597
# Best decryption:  потхикность гадна взимачиннея зыджохозминаил кыме теб самьне а всмозая гадна кыма теб нозы а пхаятны что енне чвзстзоземе сикя нипхостатимьно счестмазош чил комьхи оне вднеземе зхонсборо тил комьхи оне мшкаме иро оне мшкаме иро де иро селоро а де иро мшкозь б ний помнои окмеженаи ал кымо ий постоянно хежостно кмадость иро ий зсирже кыме пхаятне зси чихты иро эехебтихе ботохый оне вднеземе комьхи а комьхи кыма жмя нии низыхедало ламы
#
# New best llh:  -4043.545015520441
# Best decryption:  потхекность гадна вземаченнея зыджохозменаел кыме теб самьне а всмозая гадна кыма теб нозы а пхаятны что енне чвзстзоземе секя непхостатемьно счестмазош чел комьхе оне вднеземе зхонсборо тел комьхе оне мшкаме еро оне мшкаме еро де еро селоро а де еро мшкозь б ней помное окмеженае ал кымо ей постоянно хежостно кмадость еро ей зсерже кыме пхаятне зсе чехты еро эехебтехе ботохый оне вднеземе комьхе а комьхе кыма жмя нее незыхедало ламы
#
# New best llh:  -4013.1690571464087
# Best decryption:  потхекность гадна вземаченнея зыджохозменаел кыме теб самьне а всмозая гадна кыма теб нозы а пхаятны что енне чвзстзоземе секя непхостатемьно счестмазои чел комьхе оне вднеземе зхонсборо тел комьхе оне микаме еро оне микаме еро де еро селоро а де еро микозь б ней помное окмеженае ал кымо ей постоянно хежостно кмадость еро ей зсерже кыме пхаятне зсе чехты еро эехебтехе ботохый оне вднеземе комьхе а комьхе кыма жмя нее незыхедало ламы
#
# New best llh:  -3934.7822775961467
# Best decryption:  потхекность гадна вземаченнея зиджохозменаел киме теб самьне а всмозая гадна кима теб нози а пхаятни что енне чвзстзоземе секя непхостатемьно счестмазоы чел комьхе оне вднеземе зхонсборо тел комьхе оне мыкаме еро оне мыкаме еро де еро селоро а де еро мыкозь б ней помное окмеженае ал кимо ей постоянно хежостно кмадость еро ей зсерже киме пхаятне зсе чехти еро эехебтехе ботохий оне вднеземе комьхе а комьхе кима жмя нее незихедало лами
#
# New best llh:  -3879.147586266035
# Best decryption:  потвекность гадна хземаченнея зиджовозменаел киме теб самьне а хсмозая гадна кима теб нози а пваятни что енне чхзстзоземе секя непвостатемьно счестмазоы чел комьхе оне хднеземе звонсборо тел комьхе оне мыкаме еро оне мыкаме еро де еро селоро а де еро мыкозь б ней помное окмеженае ал кимо ей постоянно вежостно кмадость еро ей зсерже киме пваятне зсе чевти еро эевебтеве ботовий оне хднеземе комьхе а комьхе кима жмя нее незиведало лами
#
# New best llh:  -3871.775572142896
# Best decryption:  потвекность гадна хземаченнея зиджовозменаел киме теб самьне а хсмозая гадна кима теб нози а пваятни что енне чхзстзоземе секя непвостатемьно счестмазоы чел комьхе оне хднеземе звонсборо тел комьхе оне мыкаме еро оне мыкаме еро де еро селоро а де еро мыкозь б ней помное окмеженае ал кимо ей постоянно вежостно кмадость еро ей зсерже киме пваятне зсе чевти еро уевебтеве ботовий оне хднеземе комьхе а комьхе кима жмя нее незиведало лами
#
# New best llh:  -3859.7225860671742
# Best decryption:  потмекность гадна хзеваченнея зиджомозвенаел киве теб савьне а хсвозая гадна кива теб нози а пмаятни что енне чхзстзозеве секя непмостатевьно счествазоы чел ковьхе оне хднезеве змонсборо тел ковьхе оне выкаве еро оне выкаве еро де еро селоро а де еро выкозь б ней повное оквеженае ал киво ей постоянно межостно квадость еро ей зсерже киве пмаятне зсе чемти еро уемебтеме ботомий оне хднезеве ковьхе а ковьхе кива жвя нее незимедало лави
#
# New best llh:  -3773.020247035949
# Best decryption:  потрекность гадна хзеваченнея зиджорозвенаел киве теб савьне а хсвозая гадна кива теб нози а праятни что енне чхзстзозеве секя непростатевьно счествазоы чел ковьхе оне хднезеве зронсбомо тел ковьхе оне выкаве емо оне выкаве емо де емо селомо а де емо выкозь б ней повное оквеженае ал киво ей постоянно режостно квадость емо ей зсемже киве праятне зсе черти емо уеребтере боторий оне хднезеве ковьхе а ковьхе кива жвя нее незиредало лави
#
# New best llh:  -3740.7875790254657
# Best decryption:  потрекность гадна хзеваченнея зиджорозвенаел киве теб савьне а хсвозая гадна кива теб нози а праятни что енне чхзстзозеве секя непростатевьно счествазоы чел ковьше оне хднезеве зронсбомо тел ковьше оне выкаве емо оне выкаве емо де емо селомо а де емо выкозь б ней повное оквеженае ал киво ей постоянно режостно квадость емо ей зсемже киве праятне зсе черти емо уеребтере боторий оне хднезеве ковьше а ковьше кива жвя нее незиредало лави
#
# New best llh:  -3740.7078341738597
# Best decryption:  потрекносту гадна хзеваченнея зиджорозвенаел киве теб савуне а хсвозая гадна кива теб нози а праятни что енне чхзстзозеве секя непростатевуно счествазоы чел ковуше оне хднезеве зронсбомо тел ковуше оне выкаве емо оне выкаве емо де емо селомо а де емо выкозу б ней повное оквеженае ал киво ей постоянно режостно квадосту емо ей зсемже киве праятне зсе черти емо уеребтере боторий оне хднезеве ковуше а ковуше кива жвя нее незиредало лави
#
# New best llh:  -3740.121257400924
# Best decryption:  потрекносту гадна хзеваченнея зиджорозвенаел киве теб савуне а хсвозая гадна кива теб нози а праятни что енне чхзстзозеве секя непростатевуно счествазоы чел ковуше оне хднезеве зронсбомо тел ковуше оне выкаве емо оне выкаве емо де емо селомо а де емо выкозу б ней повное оквеженае ал киво ей постоянно режостно квадосту емо ей зсемже киве праятне зсе черти емо церебтере боторий оне хднезеве ковуше а ковуше кива жвя нее незиредало лави
#
# New best llh:  -3718.7537160353154
# Best decryption:  потрекносту гадна хлеваченнея лиджоролвенаез киве теб савуне а хсволая гадна кива теб ноли а праятни что енне чхлстлолеве секя непростатевуно счествалоы чез ковуше оне хднелеве лронсбомо тез ковуше оне выкаве емо оне выкаве емо де емо сезомо а де емо выколу б ней повное оквеженае аз киво ей постоянно режостно квадосту емо ей лсемже киве праятне лсе черти емо церебтере боторий оне хднелеве ковуше а ковуше кива жвя нее нелиредазо зави
#
# New best llh:  -3717.564723189157
# Best decryption:  потрекносту хадна глеваченнея лиджоролвенаез киве теб савуне а гсволая хадна кива теб ноли а праятни что енне чглстлолеве секя непростатевуно счествалоы чез ковуше оне гднелеве лронсбомо тез ковуше оне выкаве емо оне выкаве емо де емо сезомо а де емо выколу б ней повное оквеженае аз киво ей постоянно режостно квадосту емо ей лсемже киве праятне лсе черти емо церебтере боторий оне гднелеве ковуше а ковуше кива жвя нее нелиредазо зави
#
# New best llh:  -3677.9689135791155
# Best decryption:  потребносту хадна глеваченнея лиджоролвенаез биве тек савуне а гсволая хадна бива тек ноли а праятни что енне чглстлолеве себя непростатевуно счествалоы чез бовуше оне гднелеве лронскомо тез бовуше оне выбаве емо оне выбаве емо де емо сезомо а де емо выболу к ней повное обвеженае аз биво ей постоянно режостно бвадосту емо ей лсемже биве праятне лсе черти емо церектере которий оне гднелеве бовуше а бовуше бива жвя нее нелиредазо зави
#
# New best llh:  -3677.291459299704
# Best decryption:  потребносту жадна хлеваченнея лидгоролвенаез биве тек савуне а хсволая жадна бива тек ноли а праятни что енне чхлстлолеве себя непростатевуно счествалоы чез бовуше оне хднелеве лронскомо тез бовуше оне выбаве емо оне выбаве емо де емо сезомо а де емо выболу к ней повное обвегенае аз биво ей постоянно регостно бвадосту емо ей лсемге биве праятне лсе черти емо церектере которий оне хднелеве бовуше а бовуше бива гвя нее нелиредазо зави
#
# New best llh:  -3623.058386631962
# Best decryption:  потребносту шадна хлеваченнея лидморолвенаез биве тек савуне а хсволая шадна бива тек ноли а праятни что енне чхлстлолеве себя непростатевуно счествалоы чез бовуже оне хднелеве лронского тез бовуже оне выбаве его оне выбаве его де его сезого а де его выболу к ней повное обвеменае аз биво ей постоянно ремостно бвадосту его ей лсегме биве праятне лсе черти его церектере которий оне хднелеве бовуже а бовуже бива мвя нее нелиредазо зави
#
# New best llh:  -3622.147864238067
# Best decryption:  потребносту шазна хлеваченнея лизморолвенаед биве тек савуне а хсволая шазна бива тек ноли а праятни что енне чхлстлолеве себя непростатевуно счествалоы чед бовуже оне хзнелеве лронского тед бовуже оне выбаве его оне выбаве его зе его седого а зе его выболу к ней повное обвеменае ад биво ей постоянно ремостно бвазосту его ей лсегме биве праятне лсе черти его уеректере которий оне хзнелеве бовуже а бовуже бива мвя нее нелирезадо дави
#
# New best llh:  -3621.073273839374
# Best decryption:  потредносту шазна хлеваченнея лизморолвенаеб диве тек савуне а хсволая шазна дива тек ноли а праятни что енне чхлстлолеве седя непростатевуно счествалоы чеб довуже оне хзнелеве лронского теб довуже оне выдаве его оне выдаве его зе его себого а зе его выдолу к ней повное одвеменае аб диво ей постоянно ремостно двазосту его ей лсегме диве праятне лсе черти его уеректере которий оне хзнелеве довуже а довуже дива мвя нее нелирезабо бави
#
# New best llh:  -3597.429126558243
# Best decryption:  потредносту шазна хлеваченнея лизморолвенаех диве тек савуне а хсволая шазна дива тек ноли а праятни что енне чхлстлолеве седя непростатевуно счествалоы чех довуже оне хзнелеве лронского тех довуже оне выдаве его оне выдаве его зе его сехого а зе его выдолу к ней повное одвеменае ах диво ей постоянно ремостно двазосту его ей лсегме диве праятне лсе черти его уеректере которий оне хзнелеве довуже а довуже дива мвя нее нелирезахо хави
#
# New best llh:  -3591.3162389522445
# Best decryption:  потредносту шазна хлеваченнея лизморолвенаех диве тек савуне а хсволая шазна дива тек ноли а праятни что енне чхлстлолеве седя непростатевуно счествалоы чех довуже оне хзнелеве лронского тех довуже оне выдаве его оне выдаве его зе его сехого а зе его выдолу к ней повное одвеменае ах диво ей постоянно ремостно двазосту его ей лсегме диве праятне лсе черти его беректере которий оне хзнелеве довуже а довуже дива мвя нее нелирезахо хави
#
# New best llh:  -3584.83445592902
# Best decryption:  потредносту шамна хлеваченнея лимзоролвенаех диве тек савуне а хсволая шамна дива тек ноли а праятни что енне чхлстлолеве седя непростатевуно счествалоы чех довуже оне хмнелеве лронского тех довуже оне выдаве его оне выдаве его ме его сехого а ме его выдолу к ней повное одвезенае ах диво ей постоянно резостно двамосту его ей лсегзе диве праятне лсе черти его беректере которий оне хмнелеве довуже а довуже дива звя нее нелиремахо хави
#  12%|█▏        | 1766/15000 [00:00<00:03, 3536.61it/s]
# New best llh:  -3543.285841164411
# Best decryption:  потредносту шамна улеваченнея лимзоролвенаех диве тек савуне а усволая шамна дива тек ноли а праятни что енне чулстлолеве седя непростатевуно счествалоы чех довуже оне умнелеве лронского тех довуже оне выдаве его оне выдаве его ме его сехого а ме его выдолу к ней повное одвезенае ах диво ей постоянно резостно двамосту его ей лсегзе диве праятне лсе черти его беректере которий оне умнелеве довуже а довуже дива звя нее нелиремахо хави
#
# New best llh:  -3535.508539885943
# Best decryption:  потредносту жамна улеваченнея лимзоролвенаех диве тек савуне а усволая жамна дива тек ноли а праятни что енне чулстлолеве седя непростатевуно счествалоы чех довуше оне умнелеве лронского тех довуше оне выдаве его оне выдаве его ме его сехого а ме его выдолу к ней повное одвезенае ах диво ей постоянно резостно двамосту его ей лсегзе диве праятне лсе черти его беректере которий оне умнелеве довуше а довуше дива звя нее нелиремахо хави
#
# New best llh:  -3534.593901560348
# Best decryption:  потредность жамна улеваченнея лимзоролвенаех диве тек савьне а усволая жамна дива тек ноли а праятни что енне чулстлолеве седя непростатевьно счествалоы чех довьше оне умнелеве лронского тех довьше оне выдаве его оне выдаве его ме его сехого а ме его выдоль к ней повное одвезенае ах диво ей постоянно резостно двамость его ей лсегзе диве праятне лсе черти его беректере которий оне умнелеве довьше а довьше дива звя нее нелиремахо хави
#
# New best llh:  -3411.124712131544
# Best decryption:  потредность жамна увелаченнея вимзоровленаех диле тек сальне а условая жамна дила тек нови а праятни что енне чувствовеле седя непростательно счестлавоы чех дольше оне умневеле вронского тех дольше оне лыдале его оне лыдале его ме его сехого а ме его лыдовь к ней полное одлезенае ах дило ей постоянно резостно дламость его ей всегзе диле праятне все черти его беректере которий оне умневеле дольше а дольше дила зля нее невиремахо хали
#
# New best llh:  -3329.519486479885
# Best decryption:  потредность жимни увеличеннея вамзоровлениех дале тек сильне и условия жимни дали тек нова и приятна что енне чувствовеле седя непростительно счестливой чех дольше оне умневеле вронского тех дольше оне лйдиле его оне лйдиле его ме его сехого и ме его лйдовь к ней полное одлезение их дало ей постоянно резостно длимость его ей всегзе дале приятне все черта его беректере которай оне умневеле дольше и дольше дали зля нее неваремихо хила
#
# New best llh:  -3311.819333841309
# Best decryption:  потредность жимни увеличеннея вамзоровлениех дале тек сильне и условия жимни дали тек нова и приятна что енне чувствовеле седя непростительно счестливоу чех дольше оне умневеле вронского тех дольше оне лудиле его оне лудиле его ме его сехого и ме его лудовь к ней полное одлезение их дало ей постоянно резостно длимость его ей всегзе дале приятне все черта его беректере которай оне умневеле дольше и дольше дали зля нее неваремихо хила
#
# New best llh:  -3297.36342582699
# Best decryption:  потредность жимни увеличеннея вамборовлениех дале тек сильне и условия жимни дали тек нова и приятна что енне чувствовеле седя непростительно счестливоу чех дольше оне умневеле вронского тех дольше оне лудиле его оне лудиле его ме его сехого и ме его лудовь к ней полное одлебение их дало ей постоянно ребостно длимость его ей всегбе дале приятне все черта его зеректере которай оне умневеле дольше и дольше дали бля нее неваремихо хила
#
# New best llh:  -3290.974862024032
# Best decryption:  потребность жимни увеличеннея вамдоровлениех бале тек сильне и условия жимни бали тек нова и приятна что енне чувствовеле себя непростительно счестливоу чех больше оне умневеле вронского тех больше оне лубиле его оне лубиле его ме его сехого и ме его лубовь к ней полное обледение их бало ей постоянно редостно блимость его ей всегде бале приятне все черта его зеректере которай оне умневеле больше и больше бали для нее неваремихо хила
#
# New best llh:  -3221.3303923326703
# Best decryption:  потребность жимни увеличенная вемдоровлениех бела так сильна и условия жимни бели так нове и приятне что анна чувствовала себя непростительно счастливоу чех больше она умнавала вронского тех больше она лубила его она лубила его ма его сахого и ма его лубовь к ней полное обладание их бело ей постоянно радостно блимость его ей всегда бела приятна все черте его зарактера которей она умнавала больше и больше бели для нее неверамихо хиле
#  21%|██▏       | 3216/15000 [00:00<00:03, 3605.13it/s]
# New best llh:  -3196.352944867299
# Best decryption:  потребность жизни увеличенная вездоровлениех бела так сильна и условия жизни бели так нове и приятне что анна чувствовала себя непростительно счастливоу чех больше она узнавала вронского тех больше она лубила его она лубила его за его сахого и за его лубовь к ней полное обладание их бело ей постоянно радостно близость его ей всегда бела приятна все черте его марактера которей она узнавала больше и больше бели для нее неверазихо хиле
#
# New best llh:  -3159.618253473801
# Best decryption:  потребность жизни увеличенная вездоровлением бела так сильна и условия жизни бели так нове и приятне что анна чувствовала себя непростительно счастливоу чем больше она узнавала вронского тем больше она лубила его она лубила его за его самого и за его лубовь к ней полное обладание им бело ей постоянно радостно близость его ей всегда бела приятна все черте его характера которей она узнавала больше и больше бели для нее неверазимо миле
#
# New best llh:  -3147.423954729897
# Best decryption:  потребность жизни увеличенная выздоровлением была так сильна и условия жизни были так новы и приятны что анна чувствовала себя непростительно счастливоу чем больше она узнавала вронского тем больше она лубила его она лубила его за его самого и за его лубовь к ней полное обладание им было ей постоянно радостно близость его ей всегда была приятна все черты его характера который она узнавала больше и больше были для нее невыразимо милы
#  34%|███▍      | 5069/15000 [00:01<00:02, 3685.06it/s]
# New best llh:  -3141.7640483929217
# Best decryption:  потребность жизни увеличенная выздоровлением была так сильна и условия жизни были так новы и приятны что анна чувствовала себя непростительно счастливоу чем больше она узнавала вронского тем больше она лубила его она лубила его за его самого и за его лубовь к нее полное обладание им было ее постоянно радостно близость его ее всегда была приятна все черты его характера которые она узнавала больше и больше были для нее невыразимо милы
# 100%|██████████| 15000/15000 [00:04<00:00, 3621.01it/s]
# Best decryption:
#  потребность жизни увеличенная выздоровлением была так сильна и условия жизни были так новы и приятны что анна чувствовала себя непростительно счастливоу чем больше она узнавала вронского тем больше она лубила его она лубила его за его самого и за его лубовь к нее полное обладание им было ее постоянно радостно близость его ее всегда была приятна все черты его характера которые она узнавала больше и больше были для нее невыразимо милы
# Accuracy:  0.7878787878787878

# %% [markdown]
# Результат, как и на основе статистики биграмм, получился высокоточным.
#
# Для произвольного текста, результат во многом будет зависеть от длины сообщения, начального приближения (технически, можно застрять в локальном максимуме) а также от энтропии конкретного языка.

# %% [markdown]
# ## Часть 6.

# %% [markdown]
# Бонус: какие вы можете придумать применения для этой модели? Пляшущие человечки ведь не так часто встречаются в жизни (хотя встречаются! и это самое потрясающее во всей этой истории, но об этом я расскажу потом).

# %% [markdown]
# Конечно, подобные методологии вряд ли могут быть всерьез применены в криптографии (кажется, даже для шифра Вижинера уже непросто будет построить подобный метод, не говоря о современных алгоритмах). В тоже время, основной особенностью задачи было использование МСМС-сэмплирования для нахождения максимума функции (фактически, рассмотренное блуждание Метрополиса-Гастингса делает с большей вероятностью шаг в сторону увеличения плотности). Таким образом, рассмотренный подход может использоваться, например, как итеративный алгоритм поиска максимума функции (например, для оценки статистических характеристик распределения).
